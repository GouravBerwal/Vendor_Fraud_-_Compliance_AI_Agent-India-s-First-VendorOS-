# %% [markdown]
# # **Vendor Fraud & Compliance AI Agent (India's First “VendorOS”)** #

# %%
**Team** : BharatPitchers
**Team Member** : Gourav Berwal
**Track** : Enterprise Agents
**Course** : 5-Day AI Agents Intensive with Google
**Date** : 18-11-2025
# Out:
#   Cell In[1], line 1
#     **Team** : BharatPitchers
#     ^
# SyntaxError: invalid syntax
